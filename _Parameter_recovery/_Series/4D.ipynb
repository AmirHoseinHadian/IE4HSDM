# %%
import numpy as np
import pandas as pd

from mpmath import besseljzero
from scipy.special import gamma
from scipy.special import jv, iv
from scipy.special import jn_zeros
from scipy.optimize import minimize
from scipy.interpolate import interp1d

from scipy.stats import pearsonr
from sklearn.metrics import r2_score

import seaborn as sns
import matplotlib.pyplot as plt

# %%
def simulate_HSDM_4D(a, mu, ndt, sigma=1, dt=0.001):
    x = np.zeros(mu.shape)
    
    rt = 0
    
    while np.linalg.norm(x, 2) < a(rt):
        x += mu*dt + sigma*np.sqrt(dt)*np.random.normal(0, 1, mu.shape)
        rt += dt
    
    theta1 = np.arctan2(np.sqrt(x[3]**2 + x[2]**2 + x[1]**2), x[0])
    theta2 = np.arctan2(np.sqrt(x[3]**2 + x[2]**2), x[1])
    theta3 = np.arctan2(x[3], x[2])
    
    
    return rt+ndt, (theta1, theta2, theta3)

# %%
def series_bessel_fpt(t, a=1, sigma=1, nu=0, n=100):
    zeros = np.asarray([float(besseljzero(0, i+1)) for i in range(n)])
    fpt = np.zeros(t.shape)
    
    for i in range(t.shape[0]):
        series = np.sum((zeros**(nu+1)/jv(nu+1, zeros)) * np.exp(-(zeros**2 * sigma**2)/(2*a**2)*t[i]))
        fpt[i] = sigma**2/(2**nu * a**2 * gamma(nu + 1)) * series
        
    return interp1d(t, fpt)

# %%
def HSDM_4D_likelihood(prms, RT, Theta, N_series):
    a = prms[0]
    ndt = prms[1]
    mu = np.array([prms[2], prms[3], prms[4], prms[5]])
    
    tt = np.arange(0.001, max(RT)+0.02, 0.02)
    fpt = series_bessel_fpt(tt, a, sigma=1, nu=(mu.shape[0]-2)/2, n=N_series)
    
    log_lik = 0
    for i in range(len(RT)):
        rt, theta = RT[i], Theta[i]
        if rt - ndt > 0.001:
            mu_dot_x0 = mu[0]*np.cos(theta[0])
            mu_dot_x1 = mu[1]*np.sin(theta[0])*np.cos(theta[1]) 
            mu_dot_x2 = mu[2]*np.sin(theta[0])*np.sin(theta[1])*np.cos(theta[2])
            mu_dot_x3 = mu[3]*np.sin(theta[0])*np.sin(theta[1])*np.sin(theta[2]) 
            term1 = prms[0] * (mu_dot_x0 + mu_dot_x1 + mu_dot_x2 + mu_dot_x3)
            term2 = 0.5 * np.linalg.norm(mu, 2)**2 * (rt-ndt)
            
            density = np.exp(term1 - term2) * fpt(rt - ndt)
            
            if 0.1**14 < density:
                log_lik += -np.log(density)
            else:
                log_lik += -np.log(0.1**14)
        else:
            log_lik += -np.log(0.1**14)
        
    return log_lik

# %%
recovery_df = {'threshold_true': [],
               'threshold_estimate': [],
               'ndt_true': [],
               'ndt_estimate': [],
               'mu1_true': [],
               'mu1_estimate': [],
               'mu2_true': [],
               'mu2_estimate': [],
               'mu3_true': [],
               'mu3_estimate': [],
               'mu4_true': [],
               'mu4_estimate': []}

min_threshold = 0.5
max_threshold = 5

min_ndt = 0.1
max_ndt = 1

min_mu = -3.5
max_mu = 3.5

N_series = 250

# %%
for n in range(150):
    threshold = np.random.uniform(min_threshold, max_threshold)
    a = lambda t: threshold
    ndt = np.random.uniform(min_ndt, max_ndt)
    mu = np.array([np.random.uniform(min_mu, max_mu), 
                   np.random.uniform(min_mu, max_mu),
                   np.random.uniform(min_mu, max_mu),
                   np.random.uniform(min_mu, max_mu)])
    
    
    recovery_df['threshold_true'].append(threshold)
    recovery_df['ndt_true'].append(ndt)
    recovery_df['mu1_true'].append(mu[0])
    recovery_df['mu2_true'].append(mu[1])
    recovery_df['mu3_true'].append(mu[2])
    recovery_df['mu4_true'].append(mu[3])
    
    RT = []
    Theta = []
    
    print(n+1, end=': ')
    for i in range(250):
        rt, theta = simulate_HSDM_4D(a, mu, ndt)
        RT.append(rt)
        Theta.append(theta)
    
    print('Simulation is done!', end=' / ')
    
    min_ans = minimize(HSDM_4D_likelihood,
                       args=(RT, Theta, N_series), 
                       x0=np.array([np.random.uniform(min_threshold, max_threshold),
                                    np.random.uniform(min_ndt, max_ndt), 
                                    np.random.uniform(min_mu, max_mu),
                                    np.random.uniform(min_mu, max_mu),
                                    np.random.uniform(min_mu, max_mu),
                                    np.random.uniform(min_mu, max_mu)]),
                       method='Nelder-Mead', 
                       bounds=[(min_threshold, max_threshold), (min_ndt, max_ndt),
                               (min_mu, max_mu), (min_mu, max_mu), 
                               (min_mu, max_mu), (min_mu, max_mu)])
    
    recovery_df['threshold_estimate'].append(min_ans.x[0])
    recovery_df['ndt_estimate'].append(min_ans.x[1])
    recovery_df['mu1_estimate'].append(min_ans.x[2])
    recovery_df['mu2_estimate'].append(min_ans.x[3])
    recovery_df['mu3_estimate'].append(min_ans.x[4])
    recovery_df['mu4_estimate'].append(min_ans.x[5])
    
    print('Estimation is done!')
    
recovery_df = pd.DataFrame(recovery_df)
# Out:
# 1: Simulation is done! / Estimation is done!
# 2: Simulation is done! / Estimation is done!
# 3: Simulation is done! / Estimation is done!
# 4: Simulation is done! / Estimation is done!
# 5: Simulation is done! / Estimation is done!
# 6: Simulation is done! / Estimation is done!
# 7: Simulation is done! / Estimation is done!
# 8: Simulation is done! / Estimation is done!
# 9: Simulation is done! / Estimation is done!
# 10: Simulation is done! / Estimation is done!
# 11: Simulation is done! / Estimation is done!
# 12: Simulation is done! / Estimation is done!
# 13: Simulation is done! / Estimation is done!
# 14: Simulation is done! / Estimation is done!
# 15: Simulation is done! / Estimation is done!
# 16: Simulation is done! / Estimation is done!
# 17: Simulation is done! / Estimation is done!
# 18: Simulation is done! / Estimation is done!
# 19: Simulation is done! / Estimation is done!
# 20: Simulation is done! / Estimation is done!
# 21: Simulation is done! / Estimation is done!
# 22: Simulation is done! / Estimation is done!
# 23: Simulation is done! / Estimation is done!
# 24: Simulation is done! / Estimation is done!
# 25: Simulation is done! / Estimation is done!
# 26: Simulation is done! / Estimation is done!
# 27: Simulation is done! / Estimation is done!
# 28: Simulation is done! / Estimation is done!
# 29: Simulation is done! / Estimation is done!
# 30: Simulation is done! / Estimation is done!
# 31: Simulation is done! / Estimation is done!
# 32: Simulation is done! / Estimation is done!
# 33: Simulation is done! / Estimation is done!
# 34: Simulation is done! / Estimation is done!
# 35: Simulation is done! / Estimation is done!
# 36: Simulation is done! / Estimation is done!
# 37: Simulation is done! / Estimation is done!
# 38: Simulation is done! / Estimation is done!
# 39: Simulation is done! / Estimation is done!
# 40: Simulation is done! / Estimation is done!
# 41: Simulation is done! / Estimation is done!
# 42: Simulation is done! / Estimation is done!
# 43: Simulation is done! / Estimation is done!
# 44: Simulation is done! / Estimation is done!
# 45: Simulation is done! / Estimation is done!
# 46: Simulation is done! / Estimation is done!
# 47: Simulation is done! / Estimation is done!
# 48: Simulation is done! / Estimation is done!
# 49: Simulation is done! / Estimation is done!
# 50: Simulation is done! / Estimation is done!
# 51: Simulation is done! / Estimation is done!
# 52: Simulation is done! / Estimation is done!
# 53: Simulation is done! / Estimation is done!
# 54: Simulation is done! / Estimation is done!
# 55: Simulation is done! / Estimation is done!
# 56: Simulation is done! / Estimation is done!
# 57: Simulation is done! / Estimation is done!
# 58: Simulation is done! / Estimation is done!
# 59: Simulation is done! / Estimation is done!
# 60: Simulation is done! / Estimation is done!
# 61: Simulation is done! / Estimation is done!
# 62: Simulation is done! / Estimation is done!
# 63: Simulation is done! / Estimation is done!
# 64: Simulation is done! / Estimation is done!
# 65: Simulation is done! / Estimation is done!
# 66: Simulation is done! / Estimation is done!
# 67: Simulation is done! / Estimation is done!
# 68: Simulation is done! / Estimation is done!
# 69: Simulation is done! / Estimation is done!
# 70: Simulation is done! / Estimation is done!
# 71: Simulation is done! / Estimation is done!
# 72: Simulation is done! / Estimation is done!
# 73: Simulation is done! / Estimation is done!
# 74: Simulation is done! / Estimation is done!
# 75: Simulation is done! / Estimation is done!
# 76: Simulation is done! / Estimation is done!
# 77: Simulation is done! / Estimation is done!
# 78: Simulation is done! / Estimation is done!
# 79: Simulation is done! / Estimation is done!
# 80: Simulation is done! / Estimation is done!
# 81: Simulation is done! / Estimation is done!
# 82: Simulation is done! / Estimation is done!
# 83: Simulation is done! / Estimation is done!
# 84: Simulation is done! / Estimation is done!
# 85: Simulation is done! / Estimation is done!
# 86: Simulation is done! / Estimation is done!
# 87: Simulation is done! / Estimation is done!
# 88: Simulation is done! / Estimation is done!
# 89: Simulation is done! / Estimation is done!
# 90: Simulation is done! / Estimation is done!
# 91: Simulation is done! / Estimation is done!
# 92: Simulation is done! / Estimation is done!
# 93: Simulation is done! / Estimation is done!
# 94: Simulation is done! / Estimation is done!
# 95: Simulation is done! / Estimation is done!
# 96: Simulation is done! / Estimation is done!
# 97: Simulation is done! / Estimation is done!
# 98: Simulation is done! / Estimation is done!
# 99: Simulation is done! / Estimation is done!
# 100: Simulation is done! / Estimation is done!
# 101: Simulation is done! / Estimation is done!
# 102: Simulation is done! / Estimation is done!
# 103: Simulation is done! / Estimation is done!
# 104: Simulation is done! / Estimation is done!
# 105: Simulation is done! / Estimation is done!
# 106: Simulation is done! / Estimation is done!
# 107: Simulation is done! / Estimation is done!
# 108: Simulation is done! / Estimation is done!
# 109: Simulation is done! / Estimation is done!
# 110: Simulation is done! / Estimation is done!
# 111: Simulation is done! / Estimation is done!
# 112: Simulation is done! / Estimation is done!
# 113: Simulation is done! / Estimation is done!
# 114: Simulation is done! / Estimation is done!
# 115: Simulation is done! / Estimation is done!
# 116: Simulation is done! / Estimation is done!
# 117: Simulation is done! / Estimation is done!
# 118: Simulation is done! / Estimation is done!
# 119: Simulation is done! / Estimation is done!
# 120: Simulation is done! / Estimation is done!
# 121: Simulation is done! / Estimation is done!
# 122: Simulation is done! / Estimation is done!
# 123: Simulation is done! / Estimation is done!
# 124: Simulation is done! / Estimation is done!
# 125: Simulation is done! / Estimation is done!
# 126: Simulation is done! / Estimation is done!
# 127: Simulation is done! / Estimation is done!
# 128: Simulation is done! / Estimation is done!
# 129: Simulation is done! /

# %%
recovery_df

# %%
recovery_df.corr()

# %%
recovery_df.to_csv('Series_4d_recovery_{}.csv'.format(N_series))
